# %% [markdown]
# <a href="https://colab.research.google.com/github/DiaHere/California-Hosuing-Prices-Prediction/blob/main/Cluster_Analysis_%26_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Introduction

# %% [markdown]
# - Dataset: data about parks in 100 popular cities in the United Stataes. The data was derived from the Trust of Public Land and has been redunced by professor Jordan.
# - Purpose: Create cluster analysis of those parks by first preparing the data, visualize it, then interpret it

# %%
# Necessary Libraries
import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
df = pd.read_csv('parks_data_2024.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   City                        100 non-null    object
#  1   Population                  100 non-null    float64
#  2   Acres per 1,000 people      100 non-null    float64
#  3   Parks per 10,000 residents  100 non-null    float64
#  4   Parks as % City Area        100 non-null    float64
#  5   Fields/ Diamonds            100 non-null    float64
#  6   Tennis_dedicdated           100 non-null    float64
#  7   Pickleball_dedicated        100 non-null    float64
#  8   Pickleball_combined         100 non-null    float64
#  9   Hoops                       100 non-null    float64
#  10  Community_garden_sites      100 non-null    float64
#  11  Dog_parks                   100 non-null    float64
#  12  Playgrounds                 100 non-null    float64
#  13  Rec_senior_centers          100 non-null    float64
#  14  Restrooms                   100 non-null    float64
#  15  Skateparks                  100 non-null    float64
#  16  Splashpads                  100 non-null    float64
#  17  Swimming_pools              100 non-null    float64
#  18  Disc_golf_courses           100 non-null    float64
#  19  investment_dollars          100 non-null    float64
# dtypes: float64(19), object(1)
# memory usage: 15.8+ KB

# %%
df
# Out:
#                   City  Population  Acres per 1,000 people  \
# 0      Albuquerque, NM    553345.0               38.905204
# 1          Anaheim, CA    345538.0               13.344408
# 2        Anchorage, AK    288464.0             3022.196184
# 3        Arlington, TX    397158.0               10.869729
# 4        Arlington, VA    245695.0                7.263477
# ..                 ...         ...                     ...
# 95           Tulsa, OK    416599.0               19.502447
# 96  Virginia Beach, VA    461744.0               55.963911
# 97      Washington, DC    698878.0               13.294738
# 98         Wichita, KS    381998.0               10.731077
# 99   Winston-Salem, NC    244426.0               15.533658
#
#     Parks per 10,000 residents  Parks as % City Area  Fields/ Diamonds  \
# 0                     5.692651              0.189322          3.560166
# 1                     1.881125              0.143306          2.604634
# 2                     7.765267              0.801559          3.154640
# 3                     2.517890              0.070975          2.366816
# 4                     6.023729              0.112112          4.436395
# ..                         ...                   ...               ...
# 95                    3.264530              0.065091          5.760936
# 96                    0.021657              0.165060          2.425586
# 97                    3.419767              0.238217          2.189223
# 98                    3.036665              0.040266          2.827240
# 99                    3.641184              0.044633          2.741116
#
#     Tennis_dedicdated  Pickleball_dedicated  Pickleball_combined      Hoops  \
# 0            3.397519              1.012027             2.891505   5.060134
# 1            1.504900              1.447019             1.447019   1.504900
# 2            2.357313              0.693327             0.693327   1.975983
# 3            1.208587              0.553936             1.410018   7.830637
# 4            7.326156              0.000000             1.628035  17.094365
# ..                ...                   ...                  ...        ...
# 95           5.664920              0.768125             0.864140   2.928476
# 96           2.685471              2.468901             2.468901   7.103503
# 97           5.008027              0.429259             1.030223   6.968312
# 98           3.455515              1.623045             1.623045   3.219912
# 99           7.364192              0.900068             0.900068   3.436623
#
#     Community_garden_sites  Dog_parks  Playgrounds  Rec_senior_centers  \
# 0                 0.000000   3.975820     3.307159            1.120458
# 1                 0.011576   1.157615     1.736423            0.289404
# 2                 0.017333   2.773310     3.119973            0.207998
# 3                 0.002518   0.755367     4.230055            0.654651
# 4                 0.040701   4.070087     5.453916            1.221026
# ..                     ...        ...          ...                 ...
# 95                0.007201   0.720117     4.320702            0.384062
# 96                0.000000   1.082851     5.284313            0.303198
# 97                0.221784   2.718643     2.017520            2.003211
# 98                0.005236   1.308907     2.277499            0.471207
# 99                0.000000   1.227365     2.004697            1.391014
#
#     Restrooms  Skateparks  Splashpads  Swimming_pools  Disc_golf_courses  \
# 0    1.301177    0.000000    0.903595        0.000000           0.000000
# 1    1.736423    2.604634    0.578808        0.000000           0.000000
# 2    1.559987    1.733319    0.000000        1.733319           0.693327
# 3    1.938775    1.007156    2.014312        1.510734           0.503578
# 4    2.401351    0.407009    2.849061        2.035043           0.407009
# ..        ...         ...         ...             ...                ...
# 95   1.368222    1.200195    8.401364        1.200195           2.160351
# 96   1.191136    0.649711    0.216570        1.515992           0.649711
# 97   2.847421    0.858519    5.294200        4.721854           0.143086
# 98   2.094252    1.047126    3.141378        1.570689           1.832470
# 99   2.250170    0.409122    4.091218        3.272974           0.000000
#
#     investment_dollars
# 0           220.434307
# 1            76.151009
# 2            68.927449
# 3           112.913565
# 4           260.647703
# ..                 ...
# 95           75.332502
# 96          107.815311
# 97          485.292066
# 98           82.474460
# 99           65.392084
#
# [100 rows x 20 columns]

# %% [markdown]
# ---

# %% [markdown]
# # **PART 1**: Cluster Analysis of Parks & Facilities Data

# %% [markdown]
# **Creating k-means and hierarchical clustering analysis**

# %% [markdown]
# Firstly, normalizaing the values to analyze correctly
